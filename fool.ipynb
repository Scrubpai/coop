# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
companies = [
    # 'AAPL',
    # 'ABBV',
    # 'ABT',
    # 'ACN',
    # 'ADBE',
    # 'AIG',
    # 'AMD',
    # 'AMGN',
    # 'AMT',
    # 'AMZN',
    # 'AVGO',
    # 'AXP',
    # 'BA',
    # 'BAC',
    # 'BK', # the links are messed up
    # 'BKNG',
    # 'BLK',
    # 'BMY',
    # 'BRK.B', # has no earning transcripts
    # 'C',
    # 'CAT',
    # 'CHTR',
    # 'CL',
    # 'CMCSA',
    # 'COF',
    # 'COP',
    # 'COST',
    # 'CRM',
    # 'CSCO',
    # 'CVS',
    # 'CVX',
    # 'DHR',
    # 'DIS',
    # 'DOW',
    # 'DUK',
    # 'EMR',
    # 'EXC',
    # 'F',
    # 'FDX',
    # 'GD',
    # 'GE',
    # 'GILD',
    # 'GM',
    # 'GOOG',
    # 'GOOGL',
    # 'GS',
    # 'HD',
    # 'HON',
    # 'IBM',
    # 'INTC',
    # 'JNJ',
    # 'JPM',
    # 'KHC',
    # 'KO',
    # 'LIN',
    # 'LLY',
    # 'LMT',
    # 'LOW',
    # 'MA',
    # 'MCD',
    # 'MDLZ',
    # 'MDT',
    # 'MET',
    # 'META',
    # 'MMM',
    # 'MO',
    # 'MRK',
    # 'MS',
    # 'MSFT',
    # 'NEE',
    'NFLX',
    'NKE',
    'NVDA',
    'ORCL',
    'PEP',
    'PFE',
    'PG',
    'PM',
    'PYPL',
    'QCOM',
    'RTX',
    'SBUX',
    'SCHW', # has no earning transcripts
    'SO',
    'SPG',
    'T',
    'TGT',
    'TMO',
    'TMUS',
    'TSLA',
    'TXN',
    'UNH',
    'UNP',
    'UPS',
    'USB',
    'V',
    'VZ',
    'WBA',
    'WFC',
    'WMT',
    'XOM'
]

years = ['2015', '2016', '2017', '2018', '2019',
          '2020', '2021', '2022', '2023', '2024', '2025']

# %%
import concurrent.futures

# def fool_scraper_wrapper(url_list):
#     results = []

#     def process_url(url):
#         # Call the fool_scraper function and return the results
#         return fool_scraper(url)

#     with concurrent.futures.ThreadPoolExecutor() as executor:
#         # Submit the tasks to the executor and collect the futures
#         futures = [executor.submit(process_url, url) for url in url_list]

#         # Retrieve the results from the completed futures
#         for future in concurrent.futures.as_completed(futures):
#             result = future.result()
#             results.extend(result)

#     return results

def fool_scraper(url):
    '''
    returns the content of a seeking alpha earnings call transcript given the url
    '''
    # Send a GET request to the website
    u =  ''
    if url[0] == "h":
        u = url
    else:
        u = "http://" + url
    response = requests.get(u)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the webpage
        soup = BeautifulSoup(response.content, 'html.parser')
        # content = soup.get_text()
        # content = content.strip()

        # HEADER_CUT_OFF = " | The Motley Fool"
        # CUT_OFF_TWO = "Prepared Remarks:"
        # CUT_OFF_THREE = "\nAll earnings call transcripts\n"
        # RANDOM_SYMBOL = "\xa0"

        # AD_ONE = "10 stocks we like better than"
        # AD_TWO = "Stock Advisor returns as of "

        # header = "Section from " + content[:content.index(HEADER_CUT_OFF)] + ": "
        # content = content.replace(RANDOM_SYMBOL, " ")

        # try:
        #     content = (
        #         content[content.index(CUT_OFF_TWO) + len(CUT_OFF_TWO) : content.index(AD_ONE)]
        #         + " "
        #         + content[content.index(AD_TWO) + len(AD_TWO) : content.index(CUT_OFF_THREE)]
        #     )
        # except:
        #     pass
            
        # content = content.strip()
        para = soup.find_all(['p','h2'])
        string = ""
        for p in para:
            string += "\n\n" + p.text
        return string
    print("empty")
    return ""

# def fool_scraper(url):
#     '''
#     returns the content of a seeking alpha earnings call transcript given the url
#     '''
#     # Send a GET request to the website
#     response = requests.get("https://" + url)

#     # Check if the request was successful
#     if response.status_code == 200:
#         # Parse the webpage
#         soup = BeautifulSoup(response.content, 'html.parser')
#         content = soup.get_text()
#         content = content.strip()

#         HEADER_CUT_OFF = " | The Motley Fool"
#         CUT_OFF_TWO = "Prepared Remarks:"
#         CUT_OFF_THREE = "\nAll earnings call transcripts\n"
#         RANDOM_SYMBOL = "\xa0"

#         AD_ONE = "10 stocks we like better than"
#         AD_TWO = "Stock Advisor returns as of "

#         header = "Section from " + content[:content.index(HEADER_CUT_OFF)] + ": "
#         content = content.replace(RANDOM_SYMBOL, " ")
#         content = (
#             content[content.index(CUT_OFF_TWO) + len(CUT_OFF_TWO) : content.index(AD_ONE)]
#             + " "
#             + content[content.index(AD_TWO) + len(AD_TWO) : content.index(CUT_OFF_THREE)]
#         )
#         content = content.strip()

#         temp = functions.split_strings_from_subsection(
#             string=content,
#             header=header,
#             max_tokens=3000,
#             model=env_vars.get("GPT_MODEL"),
#         )

#     return [temp]

# %%
result = fool_scraper("https://fool.com/earnings/call-transcripts/2018/11/01/apple-inc-aapl-q4-2018-earnings-conference-call-tr.aspx")
result
download_path = "./here.txt"

with open(download_path, 'w') as df:
    df.write(result)
result
# Out:
# "\n\nFounded in 1993 by brothers Tom and David Gardner, The Motley Fool helps millions of people attain financial freedom through our website, podcasts, books, newspaper column, radio show, and premium investing services.\n\nFounded in 1993 by brothers Tom and David Gardner, The Motley Fool helps millions of people attain financial freedom through our website, podcasts, books, newspaper column, radio show, and premium investing services.\n\n\nYou’re reading a free article with opinions that may differ from The Motley Fool’s Premium Investing Services. Become a Motley Fool member today to get instant access to our top analyst recommendations, in-depth research, investing resources, and more.\nLearn More\n\n\n\nNASDAQ: AAPL\n\n\nAAPL earnings call for the period ending September 29, 2018.\n\nImage source: The Motley Fool.\n\nApple Inc.\xa0 (AAPL 0.50%)Q4\xa02018 Earnings Conference CallNov. 01, 2018, 5:00 p.m. ET\n\nContents:\n\nPrepared Remarks:\n\nOperator\n\nGood day and welcome to 
# ...

# %%
import os
file_name = 'earning_transcripts.txt'

for c in companies:
    for y in years:
        print(c, y)
        path = os.path.join(c, y, file_name)
        if(os.path.exists(path)):
            with open(path, 'r') as file:
                links = file.read().splitlines()

                for l in links:
                    content1 = fool_scraper(l)
                    filename = l.split('/')
                    
                    f = ""
                    for w in filename:
                        if "earn" in w:
                            f = w

                    if "aspx" in f:
                        f = "paragraphs" + f[:-5]

                    download_path = os.path.join(c, y, f)

                    with open(download_path, 'w') as df:
                        df.write(content1)
# Out:
# NFLX 2015
# NFLX 2016
# NFLX 2017
# NFLX 2018
# NFLX 2019
# NFLX 2020
# NFLX 2021
# NFLX 2022
# NFLX 2023
# NFLX 2024
# NFLX 2025
# NKE 2015
# NKE 2016
# NKE 2017
# NKE 2018
# NKE 2019
# NKE 2020
# NKE 2021
# NKE 2022
# NKE 2023
# NKE 2024
# NKE 2025
# NVDA 2015
# NVDA 2016
# NVDA 2017
# NVDA 2018
# NVDA 2019
# NVDA 2020
# NVDA 2021
# NVDA 2022
# NVDA 2023
# NVDA 2024
# NVDA 2025
# ORCL 2015
# ORCL 2016
# ORCL 2017
# ORCL 2018
# ORCL 2019
# ORCL 2020
# ORCL 2021
# ORCL 2022
# ORCL 2023
# ORCL 2024
# ORCL 2025
# PEP 2015
# PEP 2016
# PEP 2017
# PEP 2018
# PEP 2019
# PEP 2020
# PEP 2021
# PEP 2022
# PEP 2023
# PEP 2024
# PEP 2025
# PFE 2015
# PFE 2016
# PFE 2017
# PFE 2018
# PFE 2019
# PFE 2020
# PFE 2021
# PFE 2022
# PFE 2023
# PFE 2024
# PFE 2025
# PG 2015
# PG 2016
# PG 2017
# PG 2018
# PG 2019
# PG 2020
# PG 2021
# PG 2022
# PG 2023
# PG 2024
# PG 2025
# PM 2015
# PM 2016
# PM 2017
# PM 2018
# PM 2019
# PM 2020
# PM 2021
# PM 2022
# PM 2023
# PM 2024
# PM 2025
# PYPL 2015
# ...

# %%
import os
file_name = 'earning_transcripts.txt'

for c in companies:
    print('company:', c)
    for y in years:
        path = os.path.join(c, y, file_name)
        if(os.path.exists(path)):
            with open(path, 'r') as file:
                links = file.read().splitlines()

                for l in links:
                    content = fool_scraper(l)
                    
                    filename = l.split('/')
                    
                    f = ""
                    for w in filename:
                        if "earn" in w:
                            f = w

                    download_path = os.path.join(c, y, f)
                    
                    if(os.path.exists(download_path)):
                        os.remove(download_path)
# Out:
# company: AAPL
# company: ABBV
# company: ABT
# company: ACN
# company: ADBE
# company: AIG
# company: AMD
# company: AMGN
# company: AMT
# company: AMZN
# company: AVGO
# company: AXP
# company: BA
# company: BAC
# company: BK
# empty
# empty
# empty
# company: BKNG
# company: BLK
# company: BMY
# company: BRK.B
# company: C
# company: CAT
# company: CHTR
# company: CL
# company: CMCSA
# company: COF
# company: COP
# company: COST
# company: CRM
# company: CSCO
# company: CVS
# company: CVX
# company: DHR
# company: DIS
# company: DOW
# company: DUK
# company: EMR
# company: EXC
# company: F
# company: FDX
# company: GD
# company: GE
# company: GILD
# company: GM
# company: GOOG
# company: GOOGL
# company: GS
# company: HD
# company: HON
# company: IBM
# company: INTC
# company: JNJ
# company: JPM
# company: KHC
# company: KO
# company: LIN
# company: LLY
# company: LMT
# company: LOW
# company: MA
# company: MCD
# company: MDLZ
# company: MDT
# company: MET
# company: META
# ...
